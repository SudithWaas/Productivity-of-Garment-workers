# %%
import pandas as pd

# %%
garment = pd.read_csv('../data/garments_worker_productivity.csv')
garment.head(10)
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
# 5  1/1/2015  Quarter1      sweing  Thursday     7                   0.80
# 6  1/1/2015  Quarter1  finishing   Thursday     2                   0.75
# 7  1/1/2015  Quarter1      sweing  Thursday     3                   0.75
# 8  1/1/2015  Quarter1      sweing  Thursday     2                   0.75
# 9  1/1/2015  Quarter1      sweing  Thursday     1                   0.75
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# ...

# %%
garment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
garment = garment.replace(['finishing '], ['finishing']) 
garment = garment.replace(['sweing'], ['sewing']) 
garment.department.value_counts()
# Out:
# sewing       691
# finishing    506
# Name: department, dtype: int64

# %%
# importing libraries 
import matplotlib.pyplot as plt 
import seaborn as sns
  
# declaring data 
data = garment['department'].value_counts()
keys = ['Sewing', 'Finishing'] 
  
# define Seaborn color palette to use 
# palette_color = seaborn.color_palette('bright') 
palette_color = sns.light_palette("seagreen") 
  
# plotting data on chart 
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%') 
plt.title('Composition of the Departments')
  
# displaying chart 
plt.show()

# %%
garment['department'].value_counts()[]
# Out:
# 691

# %%
# missing values
# Check for missing values
missing_values = garment.isnull().sum()
# print(missing_values)

# Percentage of missing values
missing_percentage = (missing_values / len(garment)) * 100
print(missing_percentage)
# Out:
# date                      0.000000
# quarter                   0.000000
# department                0.000000
# day                       0.000000
# team                      0.000000
# targeted_productivity     0.000000
# smv                       0.000000
# wip                      42.272348
# over_time                 0.000000
# incentive                 0.000000
# idle_time                 0.000000
# idle_men                  0.000000
# no_of_style_change        0.000000
# no_of_workers             0.000000
# actual_productivity       0.000000
# dtype: float64

# %%
for p, r in zip(garment.columns, missing_percentage):
    print('{:25}{:.2f}'.format(p, r))
# Out:
# date                     0.00
# quarter                  0.00
# department               0.00
# day                      0.00
# team                     0.00
# targeted_productivity    0.00
# smv                      0.00
# wip                      42.27
# over_time                0.00
# incentive                0.00
# idle_time                0.00
# idle_men                 0.00
# no_of_style_change       0.00
# no_of_workers            0.00
# actual_productivity      0.00

# %%
import seaborn as sns
ax = sns.distplot(garment.targeted_productivity)
ax.set_title("Targeted Productivity")
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_6832\1652567486.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(garment.targeted_productivity)
# Text(0.5, 1.0, 'Targeted Productivity')

# %%
import seaborn as sns
ax = sns.distplot(garment.actual_productivity)
ax.set_title("Actual Productivity")
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_6832\2214003243.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(garment.actual_productivity)
# Text(0.5, 1.0, 'Actual Productivity')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# ax = sns.distplot(garment.targeted_productivity)
# ax.set_title("Targeted Productivity and Actual Productivity")

sns.histplot(garment.targeted_productivity, color='blue', alpha=0.5, kde=True, label='Targeted Productivity')
sns.histplot(garment.actual_productivity, color='red', alpha=0.5, kde=True, label='Actual Productivity')

# Adding labels and legend
plt.xlabel('Productivity')
plt.title('Targeted Productivity and Actual Productivity')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# ax = sns.distplot(garment.targeted_productivity)
# ax.set_title("Targeted Productivity and Actual Productivity")

sns.histplot(garment[garment['department'] == 'sewing'].targeted_productivity, color='blue', alpha=0.5, kde=True, label='Targeted Productivity')
sns.histplot(garment[garment['department'] == 'sewing'].actual_productivity, color='red', alpha=0.5, kde=True, label='Actual Productivity')

# Adding labels and legend
plt.xlabel('Productivity')
plt.title('Targeted Productivity and Actual Productivity of the Sewing Department')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# ax = sns.distplot(garment.targeted_productivity)
# ax.set_title("Targeted Productivity and Actual Productivity")

sns.histplot(data=garment[garment['department'] == 'finishing'].targeted_productivity, color='blue', alpha=0.5, kde=True, label='Targeted Productivity')
sns.histplot(data=garment[garment['department'] == 'finishing'].actual_productivity, color='red', alpha=0.5, kde=True, label='Actual Productivity')

# Adding labels and legend
plt.xlabel('Productivity')
plt.title('Targeted Productivity and Actual Productivity of the Finishing Department')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
garment['team'] = garment['team'].astype(str)

# %%
garment.describe().T
# Out:
#                         count         mean          std       min  \
# targeted_productivity  1197.0     0.729632     0.097891  0.070000
# smv                    1197.0    15.062172    10.943219  2.900000
# wip                     691.0  1190.465991  1837.455001  7.000000
# over_time              1197.0  4567.460317  3348.823563  0.000000
# incentive              1197.0    38.210526   160.182643  0.000000
# idle_time              1197.0     0.730159    12.709757  0.000000
# idle_men               1197.0     0.369256     3.268987  0.000000
# no_of_style_change     1197.0     0.150376     0.427848  0.000000
# no_of_workers          1197.0    34.609858    22.197687  2.000000
# actual_productivity    1197.0     0.735091     0.174488  0.233705
#
#                                25%          50%          75%           max
# targeted_productivity     0.700000     0.750000     0.800000      0.800000
# smv                       3.940000    15.260000    24.260000     54.560000
# ...

# %%
sns.boxplot(x='team',y='over_time',data=garment)
plt.show()

# %%
import numpy as np

corr=garment.corr()
mask=np.zeros(corr.shape,dtype=bool)
mask[np.triu_indices(len(mask))]=True

plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,vmin=-1,vmax=1,cmap='crest',square=True,mask=mask,linecolor='white',linewidths=1)
# Out:
# C:\Users\User1\AppData\Local\Temp\ipykernel_6832\1848693836.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=garment.corr()
# C:\Users\User1\anaconda3\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: >

# %%
from scipy.stats import shapiro

# %%
shapiro(numeric_garment)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 shapiro(garment)
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1805, in shapiro(x)
#    1802 if N < 3:
#    1803     raise ValueError("Data must be at least length 3.")
# -> 1805 x = x - np.median(x)
#    1807 a = zeros(N, 'f')
#    1808 init = 0
#
# File <__array_function__ internals>:180, in median(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3816, in median(a, axis, out, overwrite_input, keepdims)
#    3734 @array_function_dispatch(_median_dispatcher)
#    3735 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3736     """
#    3737     Compute the median along the specified axis.
#    3738
#    (...)
#    3814
#    3815     """
# -> 3816     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# ...

# %%
garment.describe()
# Out:
#        targeted_productivity          smv           wip     over_time  \
# count            1197.000000  1197.000000    691.000000   1197.000000
# mean                0.729632    15.062172   1190.465991   4567.460317
# std                 0.097891    10.943219   1837.455001   3348.823563
# min                 0.070000     2.900000      7.000000      0.000000
# 25%                 0.700000     3.940000    774.500000   1440.000000
# 50%                 0.750000    15.260000   1039.000000   3960.000000
# 75%                 0.800000    24.260000   1252.500000   6960.000000
# max                 0.800000    54.560000  23122.000000  25920.000000
#
#          incentive    idle_time     idle_men  no_of_style_change  \
# count  1197.000000  1197.000000  1197.000000         1197.000000
# mean     38.210526     0.730159     0.369256            0.150376
# std     160.182643    12.709757     3.268987            0.427848
# min       0.000000     0.000000     0.000000            0.000000
# ...

# %%
numeric_garment = garment[['smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers','targeted_productivity', 'actual_productivity']]
